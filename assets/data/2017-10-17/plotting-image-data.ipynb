# %%
import aplpy
# %matplotlib inline
import pylab as pl
import numpy as np

# %%
# !ls
# Out:
# cal1.ms			  Gaussians.fits
# cal1.uvfits		  Gaussians.im
# casa-20171011-102823.log  Interactive Colorbar.ipynb
# casa-20171011-110912.log  ipython-20171011-102826.log
# CASA Notebook.ipynb	  ipython-20171011-110914.log
# cladd.py		  make-image.py
# cleaned.flux		  make-model.py
# cleaned.image		  make-sim.py
# cleaned.image.fits	  meerkat.cfg
# cleaned.model		  meerkat-sim
# cleaned.psf		  meerkat-sim-cleaned.flux
# cleaned.psf.fits	  meerkat-sim-cleaned.image
# cleaned.residual	  meerkat-sim-cleaned.image.fits
# cleaned.residual.fits	  meerkat-sim-cleaned.model
# clean.last		  meerkat-sim-cleaned.psf
# dirty.flux		  meerkat-sim-cleaned.psf.fits
# dirty.image		  meerkat-sim-cleaned.residual
# dirty.image.fits	  my-antenna.ipynb
# dirty.model		  my-first-sim
# dirty.psf		  my-first-sim-ew
# dirty.psf.fits		  plotim.py
# dirty.residual		  plotting-image-data.ipynb
# dummy-settings.txt	  plotting-uv-data.ipynb
# EW.cfg			  pointing.txt
# example.log		  simobserve.last
# ...

# %%
F = aplpy.FITSFigure('Gaussians.fits')
F.show_colorscale(cmap='YlOrRd')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -3.672e-05 [aplpy.core]
# INFO: Auto-setting vmax to  4.075e-04 [aplpy.core]

# %%
F = aplpy.FITSFigure('meerkat-sim-dirty.image.fits')
F.show_colorscale(cmap='YlOrRd')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -1.654e-02 [aplpy.core]
# INFO: Auto-setting vmax to  2.166e-02 [aplpy.core]

# %%
F = aplpy.FITSFigure('meerkat-sim-cleaned.psf.fits')
F.show_colorscale(cmap='YlOrRd')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -9.843e-03 [aplpy.core]
# INFO: Auto-setting vmax to  1.132e-02 [aplpy.core]

# %%
F = aplpy.FITSFigure('sim.dirty.image.fits')
F.show_colorscale(cmap='YlOrRd')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -1.834e-01 [aplpy.core]
# INFO: Auto-setting vmax to  3.303e-01 [aplpy.core]

# %%
F = aplpy.FITSFigure('sim.dirty.psf.fits')
F.show_colorscale(cmap='YlOrRd')
# Out:
# INFO: Setting slices=[0, 0] [aplpy.core]
# INFO: Auto-setting vmin to -7.382e-02 [aplpy.core]
# INFO: Auto-setting vmax to  1.892e-01 [aplpy.core]
